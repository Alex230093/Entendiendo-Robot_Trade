# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex230093/Entendiendo-Robot_Trade/blob/main/PytPd_tratam_an%C3%A1lisis_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! python - V
# Out:
# Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>> ^C

# %% [markdown]
# # **Python Pandas**: tratamiento y análisis de datos

# %%
import pandas as pd
pd.set_option("display.max_rows", 15)

# con esta instrucción, la máquina va a estar desplegando siempre 15 renglones
# ¡No funcionó!! Pero decido continuar...

# %%
dataset = pd.read_csv("alquiler.csv", sep=";")

# %%
dataset
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# ...

# %%
# Vamos a ver trucos y gadgets...: empezamos en la cajita de la importación de pd

dataset.describe()
# Out:
#             Cuartos      Vacantes        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#        Mantenimiento      Impuesto
# count   2.886700e+04  2.272300e+04
# mean    2.388062e+03  2.364410e+03
# std     3.918496e+04  1.795641e+05
# min     1.000000e+00  1.000000e+00
# 25%     5.900000e+02  1.100000e+02
# 50%     9.900000e+02  2.500000e+02
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           32960 non-null  object
#  1   Distrito       32960 non-null  object
#  2   Cuartos        32960 non-null  int64
#  3   Vacantes       32960 non-null  int64
#  4   Suites         32960 non-null  int64
#  5   Area           32960 non-null  int64
#  6   Valor          32943 non-null  float64
#  7   Mantenimiento  28867 non-null  float64
#  8   Impuesto       22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dataset.head(8)
# Out:
#                  Tipo    Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación   San Borja        1         0       0    40   1700.0
# 1                Casa  Lurigancho        2         0       1   100   7000.0
# 2     Local comercial         Ate        0         4       0   150   5200.0
# 3        Departamento  Pachacámac        1         0       0    15    800.0
# 4        Departamento         Ate        1         0       0    48    800.0
# 5        Departamento    Barranco        3         1       0    70   1200.0
# 6        Departamento       Comas        2         0       0    50   1300.0
# 7  Casa en condominio         Ate        5         4       5   750  22000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# 4          230.0       NaN
# 5            NaN       NaN
# 6          301.0      17.0
# 7            NaN       NaN

# %%
# Es factible cambiar de cajita, de código a texto y viceversa: ctrl+m+m en un sentido
# y ctrl+m+y en el otro
# También, con ctrl+m+h vemos las opciones de teclado, donde están todos los métodos abreviados

# %% [markdown]
# ## Informaciones generales sobre la bdd

# %%
dataset.dtypes
# Out:
# Tipo              object
# Distrito          object
# Cuartos            int64
# Vacantes           int64
# Suites             int64
# Area               int64
# Valor            float64
# Mantenimiento    float64
# Impuesto         float64
# dtype: object

# %%
# Para manejar estos datos y hacerlo más presentable y manejable, lo convierto en DF, asignando una var

tipo_de_datos = pd.DataFrame(dataset.dtypes, columns = ["Tipos de Datos"])

# con esta instr sólo afecto la columna de la derecha; en la sig+1 caja ponemos nombre a la col de la izq

# %%
tipo_de_datos
# Out:
#               Tipos de Datos
# Tipo                  object
# Distrito              object
# Cuartos                int64
# Vacantes               int64
# Suites                 int64
# Area                   int64
# Valor                float64
# Mantenimiento        float64
# Impuesto             float64

# %%
tipo_de_datos.columns.name = "Variables"

# %%
tipo_de_datos
# Out:
# Variables     Tipos de Datos
# Tipo                  object
# Distrito              object
# Cuartos                int64
# Vacantes               int64
# Suites                 int64
# Area                   int64
# Valor                float64
# Mantenimiento        float64
# Impuesto             float64

# %%
# Para mostrar número de col y de reng

dataset.shape
# Out:
# (32960, 9)

# %%
# O bien, mostrar separadamente cada número, al asignarle el argumento con el num de col:

dataset.shape[0]
# Out:
# 32960

# %%
dataset.shape[1]
# Out:
# 9

# %%
print("La base de datos presenta {} registros (inmuebles), con {} variables".format(dataset.shape[0], dataset.shape[1]))
# Out:
# La base de datos presenta 32960 registros (inmuebles), con 9 variables

# %%
# Procedo con la actividad propuesta:

import pandas as pd
datos_Activ = [['Fulano', 12, 7.0, True],
        ['Sicrano', 15, 3.5, False],
        ['Beltrano', 18, 9.3, True]]
datos2 = pd.DataFrame(datos_Activ,
        columns = ['Alumno', 'Edad', 'Nota', 'Aprobado'])
datos2
# Out:
#      Alumno  Edad  Nota  Aprobado
# 0    Fulano    12   7.0      True
# 1   Sicrano    15   3.5     False
# 2  Beltrano    18   9.3      True

# %%
# Empiezo a ensayar. Opc A:
tipos_de_datos2 = pd.DataFrame(datos2.dtypes,
    columns = ['Tipos de Datos'])
tipos_de_datos2.columns.name = 'Variables'
tipos_de_datos2
# Out:
# Variables Tipos de Datos
# Alumno            object
# Edad               int64
# Nota             float64
# Aprobado            bool
